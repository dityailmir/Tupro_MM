# %% [markdown]
# ---
#
#
#
#
# TUGAS BESAR
# PEMROGRAMAN
# SG ADV MM
#
# ---
#
# DITYA ILMI RIZQI (1303191119)

# %% [markdown]
# Import Libraries dan Baca Data
# ----

# %%
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('Diabetes.csv')
df1 = df.head(300)

df1
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 295            6      151  ...   28        0
# 296            2      146  ...   29        1
# 297            0      126  ...   24        0
# 298           14      100  ...   46        1
# 299            8      112  ...   58        0
#
# [300 rows x 9 columns]

# %% [markdown]
# Statistic Data
# -------

# %%
# Menampilkan Informasi
df1.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 295            6      151  ...   28        0
# 296            2      146  ...   29        1
# 297            0      126  ...   24        0
# 298           14      100  ...   46        1
# 299            8      112  ...   58        0
#
# [300 rows x 9 columns]>

# %%
# Menampilkan kolerasi
df1.corr()
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.201954  ...  0.538302  0.237949
# Glucose                      0.201954  1.000000  ...  0.353178  0.429133
# BloodPressure                0.078504  0.161615  ...  0.264395  0.056202
# SkinThickness               -0.062805  0.052558  ... -0.152722  0.052016
# Insulin                      0.004000  0.385289  ...  0.081900  0.137973
# BMI                          0.054850  0.268749  ...  0.074725  0.314712
# DiabetesPedigreeFunction    -0.026493  0.207513  ...  0.082134  0.233318
# Age                          0.538302  0.353178  ...  1.000000  0.251835
# Outcome                      0.237949  0.429133  ...  0.251835  1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# Glukosa

# %%
# Menampilkan pasien yang memiliki informasi tentang glukosa
df1_glucose = df1.loc[df1['Glucose'] != 0]
df1_glucose.shape
# Out:
# (298, 9)

# %%
# Rata-rata glukosa pasien
df1_glucose['Glucose'].mean()
# Out:
# 121.90939597315436

# %%
# Cek minimum glukosa
df1_glucose['Glucose'].min()
# Out:
# 44

# %%
# Cek maksimum glukosa
df1_glucose['Glucose'].max()
# Out:
# 197

# %% [markdown]
# BloodPresure

# %%
#Menampilkan pasien yang memiliki informasi tentang tekanan darah
df1_BloodPressure = df1.loc[df1['BloodPressure'] != 0]
df1_BloodPressure.shape
# Out:
# (288, 9)

# %%
# Rata-rata tekanan darah pasien
df1_BloodPressure['BloodPressure'].mean()
# Out:
# 72.02777777777777

# %%
# Cek mininmum tekanan darah
df1_BloodPressure['BloodPressure'].min()
# Out:
# 30

# %%
# Cek maksimum tekanan darah
df1_BloodPressure['BloodPressure'].max()
# Out:
# 122

# %% [markdown]
# Insulin

# %%
#Menampilkan pasien yang memiliki informasi tentang insulin
df1_Insulin = df1.loc[df1['Insulin'] != 0]
df1_Insulin.shape
# Out:
# (148, 9)

# %%
# Rata-rata insulin pasien
df1_Insulin['Insulin'].mean()
# Out:
# 164.7972972972973

# %%
# Cek mininmum insulin
df1_Insulin['Insulin'].min()
# Out:
# 18

# %%
# Cek maksimum insulin
df1_Insulin['Insulin'].max()
# Out:
# 846

# %% [markdown]
# BMI, Glukosa, Insulin dan Tekanan Darah

# %%
## Cek penderita yang punya BMI, Glukosa, Insulin dan Tekanan Darah
df1_all = df1.loc[(df1['BMI'] != 0) & (df1['Insulin'] != 0) & (df1['BloodPressure'] != 0) & (df1['Glucose'] != 0)]
df1_all.shape
# Out:
# (147, 9)

# %%
# Cek penderita diabetes yang obesitas / overweight
diabetic_overweight_obese = ((df1_all ['BMI'] <= 30) & (df1_all ['Outcome'] == 1)).sum()
diabetic_overweight_obese
# Out:
# 8

# %%
# Cek BMI, Glukosa, Insulin dan Tekanan Darah penderita dengan nilai minimum
df1_all.min()
# Out:
# Pregnancies                  0.000
# Glucose                     71.000
# BloodPressure               30.000
# SkinThickness                7.000
# Insulin                     18.000
# BMI                         19.400
# DiabetesPedigreeFunction     0.088
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
# Cek BMI, Glukosa, Insulin dan Tekanan Darah penderita dengan nilai maksimum
df1_all.max()
# Out:
# Pregnancies                  17.000
# Glucose                     197.000
# BloodPressure               110.000
# SkinThickness                60.000
# Insulin                     846.000
# BMI                          67.100
# DiabetesPedigreeFunction      2.329
# Age                          61.000
# Outcome                       1.000
# dtype: float64

# %% [markdown]
# Outcome Diabetes

# %%
#Outcome penderita diabetes.
df1['Outcome'].value_counts()
# Out:
# 0    186
# 1    114
# Name: Outcome, dtype: int64

# %%
# Cek pasien yang tidak mengidap diabetes
count_not_diabetic = len(df1[df1['Outcome']==0])
count_not_diabetic
# Out:
# 186

# %%
df1.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.462366  110.333333  ...                  0.422199  30.962366
# 1           5.131579  138.657895  ...                  0.585360  36.859649
#
# [2 rows x 8 columns]

# %% [markdown]
# Visualisasi Data
# ---------------

# %%
plt.title('Data Umur Pasien Diabetes')
plt.xlabel('Umur')
plt.ylabel('Jumlah Pasien')
df1["Age"].hist(edgecolor = "black")

# %%
# Outcome
sns.countplot(x = 'Outcome', data = df1)

# %%
df1.hist(bins=50, figsize=(20, 15), edgecolor = "black")
plt.show()
